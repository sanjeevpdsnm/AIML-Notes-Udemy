# %%
age = 35
print(type(age))
# Out:
# <class 'int'>

# %%
height = 5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
name = "Krish"
print(name)
print(type(name))
# Out:
# Krish
# <class 'str'>

# %%
is_true = True
print(is_true)
print(type(is_true))
# Out:
# True
# <class 'bool'>

# %%
is_true = True
print(is_true)
print(type(is_true))
# Out:
# True
# <class 'bool'>

# %%
result = "hello" + 5  # This will cause an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = "hello" + 5  # This will cause an error
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "hello" + str(5) # This will cause an error
print(result)
# Out:
# hello5
